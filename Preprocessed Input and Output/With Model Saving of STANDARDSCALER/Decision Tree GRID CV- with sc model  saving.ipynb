# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[[ 'charges',]]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
import pickle as pkl
from sklearn.preprocessing import StandardScaler
scx=StandardScaler()
independent=scx.fit_transform(independent)

# %%
scy=StandardScaler()
dependent=scy.fit_transform(dependent)

# %%
from sklearn.model_selection import GridSearchCV 
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','friedman_mse','poisson','absolute_error'],
              'max_features': ['sqrt','log2'],
              'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\sabeen\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 20 fits failed out of a total of 80.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 20 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\sabeen\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\sabeen\anaconda3\Lib\site-packages\sklearn\base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\sabeen\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 1377, in fit
#     super()._fit(
#   File "C:\sabeen\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 269, in _fit
#     raise ValueError(
# ValueError: Some value(s) of y are negative which is not allowed for Poisson regression.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\sabeen\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [0.69211371 0.64446404 0.68291781 0.62564459 0.68775359 0.63509168
#  0.71217576 0.63869204        nan        nan        nan        nan
#  0.70655728 0.64687634 0.61477102 0.65053231]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'poisson', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("TheR_score valueforbestparameter{}:".format(grid.best_params_))
# Out:
# TheR_score valueforbestparameter{'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005180      0.003511         0.000000        0.000000
# 1        0.000000      0.000000         0.001101        0.002202
# 2        0.002212      0.004423         0.003630        0.004446
# 3        0.001301      0.002602         0.000000        0.000000
# 4        0.002002      0.002629         0.000701        0.001402
# 5        0.000492      0.000777         0.002776        0.003940
# 6        0.001875      0.002440         0.001504        0.002321
# 7        0.000410      0.000594         0.000000        0.000000
# 8        0.001602      0.002730         0.000000        0.000000
# 9        0.000000      0.000000         0.000000        0.000000
# 10       0.001501      0.003002         0.000000        0.000000
# 11       0.001924      0.002830         0.000000        0.000000
# 12       0.019464      0.003672         0.000401        0.000801
# 13       0.016288      0.004309         0.001212        0.002425
# 14       0.018364      0.001806         0.001601        0.002334
# 15       0.012172      0.004242         0.000401        0.000801
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8          poisson               sqrt           best
# 9          poisson               sqrt         random
# 10         poisson               log2           best
# 11         poisson               log2         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.728732
# 1   {'criterion': 'squared_error', 'max_features':...           0.711963
# 2   {'criterion': 'squared_error', 'max_features':...           0.620486
# 3   {'criterion': 'squared_error', 'max_features':...           0.638602
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.698553
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.695834
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.697185
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.687492
# 8   {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 9   {'criterion': 'poisson', 'max_features': 'sqrt...                NaN
# 10  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 11  {'criterion': 'poisson', 'max_features': 'log2...                NaN
# 12  {'criterion': 'absolute_error', 'max_features'...           0.706324
# 13  {'criterion': 'absolute_error', 'max_features'...           0.698926
# 14  {'criterion': 'absolute_error', 'max_features'...           0.566421
# 15  {'criterion': 'absolute_error', 'max_features'...           0.701717
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.578052           0.728127           0.716950
# 1            0.567172           0.673777           0.641903
# 2            0.626512           0.762015           0.672199
# 3            0.580419           0.517277           0.701100
# 4            0.646879           0.701696           0.649071
# 5            0.570113           0.541330           0.665162
# 6            0.666163           0.711060           0.723806
# 7            0.568245           0.637975           0.680470
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12           0.629014           0.708584           0.733232
# 13           0.592080           0.652151           0.678531
# 14           0.411788           0.760369           0.658498
# 15           0.537055           0.728933           0.697151
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.708708         0.692114        0.057515                3
# 1            0.627505         0.644464        0.048340                8
# 2            0.733377         0.682918        0.056563                5
# 3            0.690825         0.625645        0.069136               11
# 4            0.742569         0.687754        0.036008                4
# 5            0.703019         0.635092        0.066665               10
# 6            0.762666         0.712176        0.031710                1
# 7            0.619279         0.638692        0.043513                9
# 8                 NaN              NaN             NaN               13
# 9                 NaN              NaN             NaN               13
# 10                NaN              NaN             NaN               13
# 11                NaN              NaN             NaN               13
# 12           0.755632         0.706557        0.042748                2
# 13           0.612694         0.646876        0.039774                7
# 14           0.676779         0.614771        0.118740               12
# 15           0.587806         0.650532        0.074500                6

# %%
y_predt=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,y_predt)
r_score
# Out:
# 0.998667156135576

# %%
import pickle
import pickle as pkl
filename="finalized_model_Tree.sav"

# %%
filenamex="scx.pkl"
filenamey="scy.pkl"

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
pickle.dump(scx,open(filenamex,'wb'))
pickle.dump(scy,open(filenamey,'wb'))

# %%
scx=pickle.load(open("scx.pkl",'rb'))
scy=pickle.load(open("scy.pkl",'rb'))

# %%
preinput=scx.transform([[25,23,0,1,0]])
preinput
# Out:
# C:\sabeen\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.01155712, -1.25713795, -0.90861367,  0.98959079, -0.5074631 ]])

# %%
loaded_model=pickle.load(open("finalized_model_Tree.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([-0.90604567])

# %%
preoutput=scy.inverse_transform([result])

# %%
preoutput
# Out:
# array([[2302.3]])
