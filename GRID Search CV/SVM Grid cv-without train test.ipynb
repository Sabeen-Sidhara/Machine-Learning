# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[[ 'charges',]]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
independent=sc.fit_transform(independent)

# %%
from sklearn.model_selection import GridSearchCV 
from sklearn.svm import SVR
param_grid = {'kernel':['rbf','poly','sigmoid','linear'], 'C':[1,10,50,100,500]} 

grid = GridSearchCV(SVR(), param_grid, refit = True, verbose = 3,n_jobs=-1) 
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# C:\sabeen\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [1, 10, 50, 100, 500],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
re=grid.cv_results_

print("TheR_score valueforbestparameter{}:".format(grid.best_params_))
table=pd.DataFrame.from_dict(re)
table
# Out:
# TheR_score valueforbestparameter{'C': 500, 'kernel': 'poly'}:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.220769      0.011538         0.123433        0.003650       1
# 1        0.184626      0.006539         0.030578        0.005573       1
# 2        0.262018      0.008108         0.048421        0.004228       1
# 3        0.183292      0.007001         0.029319        0.003120       1
# 4        0.243213      0.006331         0.134172        0.006209      10
# 5        0.182771      0.014758         0.030208        0.001995      10
# 6        0.266634      0.005147         0.050428        0.002549      10
# 7        0.188996      0.010140         0.030200        0.002588      10
# 8        0.245445      0.016889         0.137078        0.006641      50
# 9        0.211414      0.020829         0.035671        0.004432      50
# 10       0.269524      0.007398         0.044689        0.003709      50
# 11       0.198728      0.012397         0.030254        0.000431      50
# 12       0.250697      0.005435         0.116162        0.008213     100
# 13       0.199707      0.012841         0.027041        0.004737     100
# 14       0.248399      0.004380         0.043469        0.005163     100
# 15       0.197430      0.006435         0.027429        0.005569     100
# 16       0.268188      0.010616         0.130556        0.010376     500
# 17       0.234598      0.008906         0.035327        0.003521     500
# 18       0.296330      0.013598         0.046116        0.006263     500
# 19       0.203045      0.021816         0.022080        0.007020     500
#
#    param_kernel                           params  split0_test_score  \
# 0           rbf        {'C': 1, 'kernel': 'rbf'}          -0.108985
# 1          poly       {'C': 1, 'kernel': 'poly'}          -0.099348
# 2       sigmoid    {'C': 1, 'kernel': 'sigmoid'}          -0.100605
# 3        linear     {'C': 1, 'kernel': 'linear'}          -0.025629
# 4           rbf       {'C': 10, 'kernel': 'rbf'}          -0.050517
# 5          poly      {'C': 10, 'kernel': 'poly'}           0.039041
# 6       sigmoid   {'C': 10, 'kernel': 'sigmoid'}           0.029716
# 7        linear    {'C': 10, 'kernel': 'linear'}           0.487873
# 8           rbf       {'C': 50, 'kernel': 'rbf'}           0.158661
# 9          poly      {'C': 50, 'kernel': 'poly'}           0.452300
# 10      sigmoid   {'C': 50, 'kernel': 'sigmoid'}           0.441079
# 11       linear    {'C': 50, 'kernel': 'linear'}           0.619032
# 12          rbf      {'C': 100, 'kernel': 'rbf'}           0.360068
# 13         poly     {'C': 100, 'kernel': 'poly'}           0.654011
# 14      sigmoid  {'C': 100, 'kernel': 'sigmoid'}           0.527367
# 15       linear   {'C': 100, 'kernel': 'linear'}           0.641464
# 16          rbf      {'C': 500, 'kernel': 'rbf'}           0.716580
# 17         poly     {'C': 500, 'kernel': 'poly'}           0.831637
# 18      sigmoid  {'C': 500, 'kernel': 'sigmoid'}           0.460917
# 19       linear   {'C': 500, 'kernel': 'linear'}           0.677474
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0           -0.106259          -0.075060          -0.099683
# 1           -0.096181          -0.066486          -0.091099
# 2           -0.094790          -0.066371          -0.091028
# 3           -0.011630           0.007866          -0.014337
# 4           -0.045096          -0.016601          -0.041415
# 5            0.040111           0.063362           0.042506
# 6            0.042770           0.059852           0.040918
# 7            0.472341           0.485102           0.475835
# 8            0.160502           0.183181           0.153780
# 9            0.436194           0.444791           0.434532
# 10           0.426827           0.443017           0.428209
# 11           0.574111           0.605923           0.592843
# 12           0.348158           0.362312           0.343255
# 13           0.612976           0.636708           0.617573
# 14           0.490754           0.520064           0.511215
# 15           0.601994           0.627339           0.628877
# 16           0.663481           0.685903           0.675065
# 17           0.760866           0.839232           0.785260
# 18           0.444127           0.467961           0.440759
# 19           0.626588           0.732421           0.633634
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.100792        -0.098156        0.012047               20
# 1           -0.092252        -0.089073        0.011666               18
# 2           -0.093774        -0.089314        0.011889               19
# 3           -0.027381        -0.014222        0.012632               16
# 4           -0.048600        -0.040446        0.012321               17
# 5            0.036594         0.044323        0.009707               14
# 6            0.018234         0.038298        0.013912               15
# 7            0.447692         0.473769        0.014239                8
# 8            0.138825         0.158990        0.014293               13
# 9            0.422321         0.438028        0.010116               10
# 10           0.397950         0.427417        0.016120               11
# 11           0.574853         0.593352        0.017494                6
# 12           0.332521         0.349263        0.010997               12
# 13           0.608877         0.626029        0.016930                4
# 14           0.485494         0.506979        0.016308                7
# 15           0.596234         0.619182        0.017199                5
# 16           0.671231         0.682452        0.018531                2
# 17           0.784613         0.800322        0.030083                1
# 18           0.384355         0.439624        0.029437                9
# 19           0.696269         0.673277        0.039486                3
