# %%
 import numpy as np
 import matplotlib.pyplot as plt
 import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[[ 'charges',]]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split    
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV 
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','friedman_mse','poisson','absolute_error'],
              'max_features': ['sqrt','log2'],
              'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'poisson', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_

grid_prediction=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_prediction)
print("TheR_score valueforbestparameter{}:".format(grid.best_params_),r_score)
table=pd.DataFrame.from_dict(re)
table
# Out:
# TheR_score valueforbestparameter{'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}: 0.5616468964774217
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009194      0.006903         0.001161        0.002321
# 1        0.005986      0.004379         0.000576        0.001152
# 2        0.004699      0.003959         0.002762        0.002355
# 3        0.004522      0.001952         0.002046        0.001396
# 4        0.001655      0.001888         0.000549        0.000925
# 5        0.004318      0.003543         0.001139        0.000779
# 6        0.000885      0.001163         0.004816        0.002903
# 7        0.003013      0.003425         0.002817        0.002642
# 8        0.002192      0.001832         0.000879        0.001758
# 9        0.004193      0.004947         0.000130        0.000260
# 10       0.004263      0.005221         0.002475        0.003877
# 11       0.003208      0.004984         0.002434        0.001676
# 12       0.007391      0.002562         0.003285        0.004256
# 13       0.006412      0.003882         0.004726        0.003553
# 14       0.012848      0.003926         0.000000        0.000000
# 15       0.009483      0.001881         0.000912        0.001825
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8          poisson               sqrt           best
# 9          poisson               sqrt         random
# 10         poisson               log2           best
# 11         poisson               log2         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.684980
# 1   {'criterion': 'squared_error', 'max_features':...           0.700353
# 2   {'criterion': 'squared_error', 'max_features':...           0.686061
# 3   {'criterion': 'squared_error', 'max_features':...           0.733365
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.705481
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.663055
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.734417
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.787499
# 8   {'criterion': 'poisson', 'max_features': 'sqrt...           0.490865
# 9   {'criterion': 'poisson', 'max_features': 'sqrt...           0.532303
# 10  {'criterion': 'poisson', 'max_features': 'log2...           0.677605
# 11  {'criterion': 'poisson', 'max_features': 'log2...           0.670793
# 12  {'criterion': 'absolute_error', 'max_features'...           0.671261
# 13  {'criterion': 'absolute_error', 'max_features'...           0.589448
# 14  {'criterion': 'absolute_error', 'max_features'...           0.669471
# 15  {'criterion': 'absolute_error', 'max_features'...           0.711096
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.589155           0.578364           0.267850
# 1            0.539826           0.509374           0.415592
# 2            0.667706           0.710533           0.727254
# 3            0.522082           0.605796           0.433476
# 4            0.572615           0.637394           0.573649
# 5            0.581009           0.601121           0.570209
# 6            0.546116           0.666907           0.523565
# 7            0.643563           0.533666           0.609250
# 8            0.629035           0.679093           0.577956
# 9            0.651262           0.639515           0.508896
# 10           0.603221           0.640171           0.574547
# 11           0.566342           0.660480           0.352644
# 12           0.660848           0.478778           0.519404
# 13           0.548222           0.661240           0.606488
# 14           0.580029           0.672867           0.588500
# 15           0.625390           0.306053           0.609720
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.678115         0.559693        0.152387               14
# 1            0.556924         0.544414        0.091997               15
# 2            0.430877         0.644486        0.108728                1
# 3            0.523796         0.563703        0.100838               13
# 4            0.671946         0.632217        0.052831                3
# 5            0.579232         0.598925        0.033618                9
# 6            0.559466         0.606094        0.080929                7
# 7            0.458044         0.606404        0.110892                6
# 8            0.576586         0.590707        0.062628               10
# 9            0.593227         0.585041        0.056567               11
# 10           0.608919         0.620892        0.035189                5
# 11           0.438249         0.537702        0.124696               16
# 12           0.677961         0.601650        0.084895                8
# 13           0.717949         0.624670        0.059083                4
# 14           0.662870         0.634747        0.041431                2
# 15           0.600845         0.570621        0.137965               12
