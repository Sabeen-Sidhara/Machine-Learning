# %%
 import numpy as np
 import matplotlib.pyplot as plt
 import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[[ 'charges',]]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaled_data=sc.fit_transform(dataset)

# %%
from sklearn.model_selection import GridSearchCV 
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','friedman_mse','poisson','absolute_error'],
              'max_features': ['sqrt','log2'],
              'splitter':['best','random']}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'poisson', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
print("TheR_score valueforbestparameter{}:".format(grid.best_params_))
# Out:
# TheR_score valueforbestparameter{'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.005819      0.006206         0.017516        0.011792
# 1        0.007492      0.005603         0.005408        0.003716
# 2        0.004720      0.003936         0.003126        0.006253
# 3        0.005590      0.004631         0.009834        0.005668
# 4        0.007368      0.004078         0.004327        0.005561
# 5        0.010432      0.004109         0.002506        0.003383
# 6        0.013807      0.019708         0.002710        0.003754
# 7        0.002002      0.004003         0.000305        0.000610
# 8        0.006086      0.006142         0.003201        0.005917
# 9        0.003002      0.006003         0.001901        0.003803
# 10       0.015854      0.004927         0.002004        0.002632
# 11       0.008272      0.007363         0.000000        0.000000
# 12       0.046961      0.016791         0.005453        0.006809
# 13       0.034537      0.009321         0.009545        0.011593
# 14       0.035806      0.005625         0.003544        0.000648
# 15       0.037514      0.012394         0.011026        0.009583
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8          poisson               sqrt           best
# 9          poisson               sqrt         random
# 10         poisson               log2           best
# 11         poisson               log2         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.704307
# 1   {'criterion': 'squared_error', 'max_features':...           0.627076
# 2   {'criterion': 'squared_error', 'max_features':...           0.673817
# 3   {'criterion': 'squared_error', 'max_features':...           0.727076
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.674818
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.632051
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.639609
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.587319
# 8   {'criterion': 'poisson', 'max_features': 'sqrt...           0.727912
# 9   {'criterion': 'poisson', 'max_features': 'sqrt...           0.562613
# 10  {'criterion': 'poisson', 'max_features': 'log2...           0.719576
# 11  {'criterion': 'poisson', 'max_features': 'log2...           0.659520
# 12  {'criterion': 'absolute_error', 'max_features'...           0.681001
# 13  {'criterion': 'absolute_error', 'max_features'...           0.710890
# 14  {'criterion': 'absolute_error', 'max_features'...           0.730334
# 15  {'criterion': 'absolute_error', 'max_features'...           0.723115
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.685291           0.745189           0.706854
# 1            0.553865           0.650010           0.624597
# 2            0.554916           0.774840           0.687403
# 3            0.621760           0.698455           0.676923
# 4            0.593606           0.680615           0.749310
# 5            0.571254           0.647332           0.609877
# 6            0.434208           0.717579           0.597302
# 7            0.613918           0.629773           0.606649
# 8            0.617092           0.746347           0.706851
# 9            0.619660           0.684123           0.683243
# 10           0.594373           0.777549           0.633403
# 11           0.471969           0.712737           0.756367
# 12           0.569537           0.719520           0.672211
# 13           0.550974           0.706718           0.562908
# 14           0.616247           0.756494           0.745233
# 15           0.590839           0.680926           0.741544
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.715640         0.711456        0.019557                3
# 1            0.601852         0.611480        0.032595               16
# 2            0.491000         0.636395        0.100943               11
# 3            0.672857         0.679414        0.034662                6
# 4            0.665644         0.672799        0.049481                8
# 5            0.605991         0.613301        0.025856               15
# 6            0.723204         0.622380        0.105416               14
# 7            0.688674         0.625267        0.034514               13
# 8            0.760634         0.711767        0.050659                2
# 9            0.608886         0.631705        0.046569               12
# 10           0.698344         0.684649        0.064520                4
# 11           0.642996         0.648718        0.097032               10
# 12           0.747667         0.677987        0.060637                7
# 13           0.741492         0.654596        0.080723                9
# 14           0.724425         0.714547        0.050420                1
# 15           0.661888         0.679662        0.052772                5
