# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, dtype=int, drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[[ 'charges',]]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split    
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV 
from sklearn.ensemble import RandomForestRegressor
param_grid = {'criterion':['squared_error','friedman_mse','poisson','absolute_error'],
              'max_features': ['sqrt','log2'],
              'n_estimators':[50,100]} 

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# C:\sabeen\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'poisson', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

grid_prediction=grid.predict(x_test)
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_prediction)
print("TheR_score valueforbestparameter{}:".format(grid.best_params_),r_score)
table=pd.DataFrame.from_dict(re)
table
# Out:
# TheR_score valueforbestparameter{'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}: 0.8763115171468472
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.156142      0.008560         0.010340        0.001651
# 1        0.312834      0.015888         0.012841        0.002198
# 2        0.160377      0.016725         0.006476        0.001051
# 3        0.310871      0.016309         0.011404        0.001628
# 4        0.170389      0.018815         0.009789        0.003784
# 5        0.267552      0.006704         0.012383        0.002457
# 6        0.133815      0.004601         0.006177        0.003202
# 7        0.268861      0.005162         0.011439        0.001937
# 8        0.144562      0.006183         0.007423        0.002801
# 9        0.292400      0.013198         0.014240        0.001309
# 10       0.142152      0.005134         0.006858        0.001212
# 11       0.275411      0.004251         0.012289        0.002076
# 12       0.371118      0.009460         0.006922        0.003670
# 13       0.740874      0.018598         0.010844        0.002803
# 14       0.358253      0.011655         0.004845        0.003260
# 15       0.645359      0.025672         0.008314        0.001728
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 50
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 50
# 3    squared_error               log2                100
# 4     friedman_mse               sqrt                 50
# 5     friedman_mse               sqrt                100
# 6     friedman_mse               log2                 50
# 7     friedman_mse               log2                100
# 8          poisson               sqrt                 50
# 9          poisson               sqrt                100
# 10         poisson               log2                 50
# 11         poisson               log2                100
# 12  absolute_error               sqrt                 50
# 13  absolute_error               sqrt                100
# 14  absolute_error               log2                 50
# 15  absolute_error               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.802106
# 1   {'criterion': 'squared_error', 'max_features':...           0.809950
# 2   {'criterion': 'squared_error', 'max_features':...           0.806400
# 3   {'criterion': 'squared_error', 'max_features':...           0.805930
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.800448
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.805200
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.819422
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.808419
# 8   {'criterion': 'poisson', 'max_features': 'sqrt...           0.801971
# 9   {'criterion': 'poisson', 'max_features': 'sqrt...           0.807185
# 10  {'criterion': 'poisson', 'max_features': 'log2...           0.806273
# 11  {'criterion': 'poisson', 'max_features': 'log2...           0.799735
# 12  {'criterion': 'absolute_error', 'max_features'...           0.805085
# 13  {'criterion': 'absolute_error', 'max_features'...           0.810971
# 14  {'criterion': 'absolute_error', 'max_features'...           0.795144
# 15  {'criterion': 'absolute_error', 'max_features'...           0.798467
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.765210           0.835002           0.823522
# 1            0.767843           0.838548           0.829579
# 2            0.769768           0.838887           0.828170
# 3            0.766316           0.834241           0.830690
# 4            0.767926           0.832891           0.822237
# 5            0.776223           0.835281           0.825957
# 6            0.772961           0.832955           0.829385
# 7            0.779588           0.837029           0.828098
# 8            0.769666           0.839451           0.830841
# 9            0.772001           0.837782           0.836000
# 10           0.781324           0.831449           0.828754
# 11           0.767324           0.832299           0.830243
# 12           0.766143           0.839675           0.827453
# 13           0.777421           0.841300           0.830992
# 14           0.779641           0.832113           0.815001
# 15           0.773101           0.831795           0.830990
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.760006         0.797169        0.030175               14
# 1            0.761667         0.801518        0.031470                5
# 2            0.757378         0.800121        0.031866                8
# 3            0.763255         0.800086        0.030444                9
# 4            0.752663         0.795233        0.030765               15
# 5            0.756351         0.799802        0.029719               10
# 6            0.758581         0.802661        0.030783                3
# 7            0.764206         0.803468        0.027818                2
# 8            0.763307         0.801047        0.030895                6
# 9            0.757532         0.802100        0.032682                4
# 10           0.755213         0.800603        0.029010                7
# 11           0.760357         0.797992        0.030256               13
# 12           0.757799         0.799231        0.032490               11
# 13           0.758489         0.803834        0.031452                1
# 14           0.754049         0.795190        0.027166               16
# 15           0.756384         0.798147        0.030273               12

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:")) 
children_input=float(input("Children:")) 
sex_male_input=int(input("Sex Male 0 or 1:")) 
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 25
# BMI: 32
# Children: 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[46925.1510862]

# %%
import pickle  
filename="finalized_model_Forest.sav"

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
preinput = sc.transform([[25,23,0,1,0]])
preinput
# Out:
# C:\sabeen\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-1.03919296, -1.2410888 , -0.90788827,  1.01127431, -0.49929923]])

# %%
loaded_model=pickle.load(open("finalized_model_Forest.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([3021.4238139])
